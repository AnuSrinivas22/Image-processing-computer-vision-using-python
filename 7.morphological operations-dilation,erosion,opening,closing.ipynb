# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------
# Load Image (Binary or Grayscale)
# -----------------------------
img = (cv2.imread("D:\IP_CV\j.png", 0))  # Replace with your image file

# Convert grayscale to binary
_, binary = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# -----------------------------
# Define Structuring Element (Kernel)
# -----------------------------
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
# Try MORPH_ELLIPSE or MORPH_CROSS for different effects

# -----------------------------
# Apply Morphological Operations
# -----------------------------

# 1. Dilation - Expands white regions (adds pixels to object boundaries)
dilated = cv2.dilate(binary, kernel, iterations=1)

# 2. Erosion - Shrinks white regions (removes pixels from object boundaries)
eroded = cv2.erode(binary, kernel, iterations=1)

# 3. Opening - Erosion followed by dilation (removes small white noise)
opened = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)

# 4. Closing - Dilation followed by erosion (fills small holes)
closed = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)

# -----------------------------
# Display Results
# -----------------------------
titles = ['Original Binary Image', 'Dilation', 'Erosion', 'Opening', 'Closing']
images = [binary, dilated, eroded, opened, closed]

plt.figure(figsize=(12, 8))
for i in range(5):
    plt.subplot(2, 3, i+1)
    plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.axis('off')

plt.tight_layout()
plt.show()
